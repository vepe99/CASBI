# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_parquet('/export/data/vgiusepp/data/full_dataframe/dataframe/dataframe.parquet')

# %%
data.head()
# Out:
#         feh       ofe  star_log10mass  gas_log10mass  dm_log10mass  \
# 0 -2.554862  0.088439        6.789908       8.656723      9.694663
# 1 -2.120942  0.106902        6.789908       8.656723      9.694663
# 2 -2.571109 -0.159409        6.789908       8.656723      9.694663
# 3 -2.605765  0.170587        6.789908       8.656723      9.694663
# 4 -2.457028  0.232366        6.789908       8.656723      9.694663
#
#    infall_time  redshift         a  mean_metallicity  mean_FeMassFrac  \
# 0     1.311857  4.561225  0.179816          0.000137         0.000006
# 1     1.311857  4.561225  0.179816          0.000137         0.000006
# 2     1.311857  4.561225  0.179816          0.000137         0.000006
# 3     1.311857  4.561225  0.179816          0.000137         0.000006
# 4     1.311857  4.561225  0.179816          0.000137         0.000006
#
#    mean_OMassFrac  std_metallicity  std_FeMassFrac  std_OMassFrac  \
# 0        0.000063         0.000086        0.000004        0.00004
# ...

# %%
print('star mass min:', data['star_log10mass'].min())
print('star belonging to the smallest galaxy: \n')
data[data['star_log10mass']==data['star_log10mass'].min()]
# Out:
# star mass min: 4.711969898733544
# star belonging to the smallest galaxy:
#                 feh       ofe  star_log10mass  gas_log10mass  dm_log10mass  \
# 197686329 -4.257980  0.702118         4.71197       7.368332      8.319556
# 197686330 -3.734077  0.659101         4.71197       7.368332      8.319556
# 197686331 -4.105195  0.695094         4.71197       7.368332      8.319556
# 197686332 -3.369116  0.687050         4.71197       7.368332      8.319556
# 197686333 -3.914359  0.713098         4.71197       7.368332      8.319556
# ...             ...       ...             ...            ...           ...
# 197686665 -3.201442  0.646763         4.71197       7.368332      8.319556
# 197686666 -3.769916  0.659156         4.71197       7.368332      8.319556
# 197686667 -3.073166  0.689426         4.71197       7.368332      8.319556
# 197686668 -4.240587  0.630395         4.71197       7.368332      8.319556
# ...
